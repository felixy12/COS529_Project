# %% [markdown]
# ## Import statements and constants

# %%
import json
import os
from collections import Counter

vid_keep_thresh = 0.6
class_keep_thresh = 50
person_detection_filepath = '/n/fs/visualai-scr/felixy/Classes/COS529/COS529_Project/YOLO/person_fraction.txt'

txt_file_dir = '/n/fs/visualai-scr/vramaswamy/COS529_project/data/UCF-101/ucfTrainTestlist'
txt_filepaths = [os.path.join(txt_file_dir, x) for x in ['testlist01.txt', 'trainlist01.txt']]

json_filepaths = ['/n/fs/visualai-scr/Data/UCF101Images/ucfTrainTestlist/ucf101_01.json'.format(x) for x in ['', 'Greyed']]

# %% [markdown]
# ## Filter out videos and classes

# %%
def get_class_from_name(vid_name):
    return vid_name.split('_')[1]

def get_person_fractions(filepath):
    person_fraction_dict = {}
    with open(person_detection_filepath) as f:
        for line in f:
            vid_name, fraction = line.strip().split()
            person_fraction_dict[vid_name] = float(fraction)
    return person_fraction_dict

def get_name_blacklist(person_fraction_dict):
    print('Removing names with less than {}% frames kept'.format(vid_keep_thresh*100))
    print('-'*40)
    blacklist = []
    count_total = Counter()
    count_remove = Counter()
    count_keep = Counter()
    for vid_name, fraction in person_fraction_dict.items():
        vid_class = get_class_from_name(vid_name)
        count_total[vid_class] += 1
        if fraction < vid_keep_thresh:
            blacklist.append(vid_name)
            count_remove[vid_class] += 1
        else:
            count_keep[vid_class] += 1
    print('Total number of videos removed: {}\n'.format(len(blacklist)))
    return blacklist, (count_total, count_remove, count_keep)

def get_class_blacklist(count_remove):
    print('Removing classes with less than {} videos'.format(class_keep_thresh))
    print('-'*40)
    class_blacklist = []
    vid_remove_count = 0
    for class_name, c in counts[2].items():
        if c < class_keep_thresh:
            class_blacklist.append(class_name)
            vid_remove_count += c
    print('Total number of classes removed: {}'.format(len(class_blacklist)))
    print('Total number of videos removed: {}'.format(vid_remove_count))
    return class_blacklist

# %%
person_fraction_dict = get_person_fractions(person_detection_filepath)
name_blacklist, counts = get_name_blacklist(person_fraction_dict)
class_blacklist = get_class_blacklist(counts[2])
# Out:
# Removing names with less than 60.0% frames kept
# ----------------------------------------
# Total number of videos removed: 3372
#
# Removing classes with less than 50 videos
# ----------------------------------------
# Total number of classes removed: 16
# Total number of videos removed: 460

# %%
13320 - 3372 - 460
# Out:
# 9488

# %% [markdown]
# ## Filter from files

# %%
def filter_from_txt(filepath, name_blacklist, class_blacklist):
    filepath_split = os.path.split(filepath)
    out_filepath = os.path.join(filepath_split[0], 'filtered_{}'.format(filepath_split[-1]))
    out_file = open(out_filepath, 'w')
    
    print('Filtering videos for file {}'.format(filepath_split[-1]))
    print('-'*40)
    num_before = 0
    num_after = 0
    with open(filepath, 'r') as in_file:
        for line in in_file:
            num_before += 1
            path = line.strip().split(' ')[0]
            class_name, vid_name = os.path.split(path)
            vid_name = vid_name[:-4]
            if not (class_name in class_blacklist or vid_name in name_blacklist):
                out_file.write(line)
                num_after += 1
    print('Number of videos before filtering: {}'.format(num_before))
    print('Number of videos after filtering: {}\n'.format(num_after))
    out_file.close()
    
def filter_from_json(filepath, name_blacklist, class_blacklist):
    filepath_split = os.path.split(filepath)
    out_filepath = os.path.join(filepath_split[0], 'filtered_{}'.format(filepath_split[-1]))
    print('Filtering videos for file {}'.format(filepath_split[-1]))
    print('-'*40)
    num_train = [0, 0] # [Before, After]
    num_test = [0, 0] # [Before, After]
    data = json.load(open(filepath))
    database = data['database']
    new_database = {}
    for vid_name in database.keys():
        class_name = get_class_from_name(vid_name)
        split = database[vid_name]['subset']
        if split == 'training': num_train[0] += 1
        elif split == 'validation': num_test[0] += 1
        if not (class_name in class_blacklist or vid_name in name_blacklist):
            new_database[vid_name] = database[vid_name]
            if split == 'training': num_train[1] += 1
            elif split == 'validation': num_test[1] += 1
    data['database'] = new_database
    print('Number of training videos before/after filtering: {}/{}'.format(num_train[0], num_train[1]))
    print('Number of testing videos before/after filtering: {}/{}'.format(num_test[0], num_test[1]))
    print('Total number of new samples: {}\n'.format(len(new_database)))
    with open(out_filepath, 'w') as out_f:
        json.dump(data, out_f)

# %%
for txt_filepath in txt_filepaths:
    filter_from_txt(txt_filepath, name_blacklist, class_blacklist)
# Out:
# Filtering videos for file testlist01.txt
# ----------------------------------------
# Number of videos before filtering: 3783
# Number of videos after filtering: 2717
#
# Filtering videos for file trainlist01.txt
# ----------------------------------------
# Number of videos before filtering: 9537
# Number of videos after filtering: 6771

# %%
for json_filepath in json_filepaths:
    filter_from_json(json_filepath, name_blacklist, class_blacklist)
# Out:
# Filtering videos for file ucf101_01.json
# ----------------------------------------
# Number of training videos before/after filtering: 9537/6771
# Number of testing videos before/after filtering: 3783/2717
# Total number of new samples: 9488
#
# Filtering videos for file ucf101_01.json
# ----------------------------------------
# Number of training videos before/after filtering: 9537/6771
# Number of testing videos before/after filtering: 3783/2717
# Total number of new samples: 9488

# %%
data = json.load(open('/n/fs/visualai-scr/Data/UCF101Images/ucfTrainTestlist/ucf101_01.json'))

# %%
print(len(data['database']))
# Out:
# 13320

# %%
data2 = json.load(open('/n/fs/visualai-scr/Data/UCF101Images/ucfTrainTestlist/filtered_ucf101_01.json'))

# %%
data2
# Out:
# {'labels': ['ApplyEyeMakeup',
#   'ApplyLipstick',
#   'Archery',
#   'BabyCrawling',
#   'BalanceBeam',
#   'BandMarching',
#   'BaseballPitch',
#   'Basketball',
#   'BasketballDunk',
#   'BenchPress',
#   'Biking',
#   'Billiards',
#   'BlowDryHair',
#   'BlowingCandles',
#   'BodyWeightSquats',
#   'Bowling',
#   'BoxingPunchingBag',
#   'BoxingSpeedBag',
#   'BreastStroke',
#   'BrushingTeeth',
#   'CleanAndJerk',
#   'CliffDiving',
#   'CricketBowling',
#   'CricketShot',
#   'CuttingInKitchen',
#   'Diving',
#   'Drumming',
#   'Fencing',
#   'FieldHockeyPenalty',
#   'FloorGymnastics',
#   'FrisbeeCatch',
#   'FrontCrawl',
#   'GolfSwing',
#   'Haircut',
#   'Hammering',
#   'HammerThrow',
#   'HandstandPushups',
#   'HandstandWalking',
#   'HeadMassage',
#   'HighJump',
#   'HorseRace',
#   'HorseRiding',
#   'HulaHoop',
#   'IceDancing',
#   'JavelinThrow',
#   'JugglingBalls',
#   'JumpingJack',
#   'JumpRope',
#   'Kayaking',
#   'Knitting',
#   'LongJump',
#   'Lunges',
#   'MilitaryParade',
#   'Mixing',
#   'MoppingFloor',
#   'Nunchucks',
#   'ParallelBars',
#   'PizzaTossing',
#   'PlayingCello',
#   'PlayingDaf',
#   'PlayingDhol',
#   'PlayingFlute',
#   'PlayingGuitar',
#   'PlayingPiano',
#   'PlayingSitar',
#   'PlayingTabla',
#   'PlayingViolin',
#   'PoleVault',
#   'PommelHorse',
#   'PullUps',
#   'Punch',
#   'PushUps',
#   'Rafting',
#   'RockClimbingIndoor',
#   'RopeClimbing',
#   'Rowing',
#   'SalsaSpin',
#   'ShavingBeard',
#   'Shotput',
#   'SkateBoarding',
#   'Skiing',
#   'Skijet',
#   'SkyDiving',
#   'SoccerJuggling',
#   'SoccerPenalty',
#   'StillRings',
#   'SumoWrestling',
#   'Surfing',
#   'Swing',
#   'TableTennisShot',
#   'TaiChi',
#   'TennisSwing',
#   'ThrowDiscus',
#   'TrampolineJumping',
#   'Typing',
#   'UnevenBars',
#   'VolleyballSpiking',
#   'WalkingWithDog',
#   'WallPushups',
#   'WritingOnBoard',
#   'YoYo'],
#  'database': {'v_ApplyEyeMakeup_g08_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 122]}},
#   'v_ApplyEyeMakeup_g08_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 119]}},
#   'v_ApplyEyeMakeup_g08_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 148]}},
#   'v_ApplyEyeMakeup_g08_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 226]}},
#   'v_ApplyEyeMakeup_g08_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 278]}},
#   'v_ApplyEyeMakeup_g09_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 178]}},
#   'v_ApplyEyeMakeup_g09_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 260]}},
#   'v_ApplyEyeMakeup_g09_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 212]}},
#   'v_ApplyEyeMakeup_g09_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 193]}},
#   'v_ApplyEyeMakeup_g09_c06': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 190]}},
#   'v_ApplyEyeMakeup_g09_c07': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 263]}},
#   'v_ApplyEyeMakeup_g10_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 155]}},
#   'v_ApplyEyeMakeup_g10_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 100]}},
#   'v_ApplyEyeMakeup_g10_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 108]}},
#   'v_ApplyEyeMakeup_g10_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 126]}},
#   'v_ApplyEyeMakeup_g10_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 122]}},
#   'v_ApplyEyeMakeup_g11_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 142]}},
#   'v_ApplyEyeMakeup_g11_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 180]}},
#   'v_ApplyEyeMakeup_g11_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 127]}},
#   'v_ApplyEyeMakeup_g11_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 140]}},
#   'v_ApplyEyeMakeup_g11_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 182]}},
#   'v_ApplyEyeMakeup_g12_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 228]}},
#   'v_ApplyEyeMakeup_g12_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 122]}},
#   'v_ApplyEyeMakeup_g12_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 143]}},
#   'v_ApplyEyeMakeup_g12_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 210]}},
#   'v_ApplyEyeMakeup_g12_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 129]}},
#   'v_ApplyEyeMakeup_g12_c06': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 214]}},
#   'v_ApplyEyeMakeup_g13_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 177]}},
#   'v_ApplyEyeMakeup_g13_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 101]}},
#   'v_ApplyEyeMakeup_g13_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 170]}},
#   'v_ApplyEyeMakeup_g13_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 122]}},
#   'v_ApplyEyeMakeup_g13_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 121]}},
#   'v_ApplyEyeMakeup_g13_c06': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 139]}},
#   'v_ApplyEyeMakeup_g14_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 187]}},
#   'v_ApplyEyeMakeup_g14_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 188]}},
#   'v_ApplyEyeMakeup_g14_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 239]}},
#   'v_ApplyEyeMakeup_g14_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 134]}},
#   'v_ApplyEyeMakeup_g14_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 162]}},
#   'v_ApplyEyeMakeup_g15_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 171]}},
#   'v_ApplyEyeMakeup_g15_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 195]}},
#   'v_ApplyEyeMakeup_g15_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 234]}},
#   'v_ApplyEyeMakeup_g15_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 189]}},
#   'v_ApplyEyeMakeup_g15_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 261]}},
#   'v_ApplyEyeMakeup_g15_c06': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 199]}},
#   'v_ApplyEyeMakeup_g15_c07': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 184]}},
#   'v_ApplyEyeMakeup_g16_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 127]}},
#   'v_ApplyEyeMakeup_g16_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 235]}},
#   'v_ApplyEyeMakeup_g16_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 116]}},
#   'v_ApplyEyeMakeup_g16_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 100]}},
#   'v_ApplyEyeMakeup_g16_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 203]}},
#   'v_ApplyEyeMakeup_g17_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 118]}},
#   'v_ApplyEyeMakeup_g17_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 175]}},
#   'v_ApplyEyeMakeup_g17_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 96]}},
#   'v_ApplyEyeMakeup_g17_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 107]}},
#   'v_ApplyEyeMakeup_g17_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 184]}},
#   'v_ApplyEyeMakeup_g18_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 161]}},
#   'v_ApplyEyeMakeup_g18_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 172]}},
#   'v_ApplyEyeMakeup_g18_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 159]}},
#   'v_ApplyEyeMakeup_g18_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 226]}},
#   'v_ApplyEyeMakeup_g18_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 189]}},
#   'v_ApplyEyeMakeup_g19_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 182]}},
#   'v_ApplyEyeMakeup_g19_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 245]}},
#   'v_ApplyEyeMakeup_g19_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 128]}},
#   'v_ApplyEyeMakeup_g19_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 133]}},
#   'v_ApplyEyeMakeup_g20_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 184]}},
#   'v_ApplyEyeMakeup_g20_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 160]}},
#   'v_ApplyEyeMakeup_g20_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 132]}},
#   'v_ApplyEyeMakeup_g20_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 222]}},
#   'v_ApplyEyeMakeup_g20_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 115]}},
#   'v_ApplyEyeMakeup_g20_c06': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 183]}},
#   'v_ApplyEyeMakeup_g21_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 183]}},
#   'v_ApplyEyeMakeup_g21_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 97]}},
#   'v_ApplyEyeMakeup_g21_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 129]}},
#   'v_ApplyEyeMakeup_g21_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 229]}},
#   'v_ApplyEyeMakeup_g21_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 92]}},
#   'v_ApplyEyeMakeup_g22_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 172]}},
#   'v_ApplyEyeMakeup_g22_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 259]}},
#   'v_ApplyEyeMakeup_g22_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 149]}},
#   'v_ApplyEyeMakeup_g22_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 210]}},
#   'v_ApplyEyeMakeup_g22_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 245]}},
#   'v_ApplyEyeMakeup_g23_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 137]}},
#   'v_ApplyEyeMakeup_g23_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 133]}},
#   'v_ApplyEyeMakeup_g23_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 127]}},
#   'v_ApplyEyeMakeup_g23_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 202]}},
#   'v_ApplyEyeMakeup_g23_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 206]}},
#   'v_ApplyEyeMakeup_g23_c06': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 142]}},
#   'v_ApplyEyeMakeup_g24_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 107]}},
#   'v_ApplyEyeMakeup_g24_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 104]}},
#   'v_ApplyEyeMakeup_g24_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 210]}},
#   'v_ApplyEyeMakeup_g24_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 201]}},
#   'v_ApplyEyeMakeup_g24_c06': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 224]}},
#   'v_ApplyEyeMakeup_g24_c07': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 196]}},
#   'v_ApplyEyeMakeup_g25_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 243]}},
#   'v_ApplyEyeMakeup_g25_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 131]}},
#   'v_ApplyEyeMakeup_g25_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 127]}},
#   'v_ApplyEyeMakeup_g25_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 179]}},
#   'v_ApplyEyeMakeup_g25_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 95]}},
#   'v_ApplyEyeMakeup_g25_c06': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 111]}},
#   'v_ApplyEyeMakeup_g25_c07': {'subset': 'training',
#    'annotations': {'label': 'ApplyEyeMakeup', 'segment': [1, 147]}},
#   'v_ApplyLipstick_g08_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 183]}},
#   'v_ApplyLipstick_g08_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 221]}},
#   'v_ApplyLipstick_g08_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 272]}},
#   'v_ApplyLipstick_g08_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 312]}},
#   'v_ApplyLipstick_g09_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 101]}},
#   'v_ApplyLipstick_g09_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 246]}},
#   'v_ApplyLipstick_g09_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 249]}},
#   'v_ApplyLipstick_g09_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 212]}},
#   'v_ApplyLipstick_g10_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 107]}},
#   'v_ApplyLipstick_g10_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 141]}},
#   'v_ApplyLipstick_g10_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 119]}},
#   'v_ApplyLipstick_g10_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 249]}},
#   'v_ApplyLipstick_g11_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 145]}},
#   'v_ApplyLipstick_g11_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 201]}},
#   'v_ApplyLipstick_g11_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 110]}},
#   'v_ApplyLipstick_g11_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 159]}},
#   'v_ApplyLipstick_g12_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 200]}},
#   'v_ApplyLipstick_g12_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 108]}},
#   'v_ApplyLipstick_g12_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 143]}},
#   'v_ApplyLipstick_g12_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 279]}},
#   'v_ApplyLipstick_g12_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 180]}},
#   'v_ApplyLipstick_g13_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 215]}},
#   'v_ApplyLipstick_g13_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 157]}},
#   'v_ApplyLipstick_g13_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 166]}},
#   'v_ApplyLipstick_g13_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 212]}},
#   'v_ApplyLipstick_g14_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 178]}},
#   'v_ApplyLipstick_g14_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 192]}},
#   'v_ApplyLipstick_g14_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 176]}},
#   'v_ApplyLipstick_g14_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 107]}},
#   'v_ApplyLipstick_g15_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 162]}},
#   'v_ApplyLipstick_g15_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 138]}},
#   'v_ApplyLipstick_g15_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 135]}},
#   'v_ApplyLipstick_g15_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 153]}},
#   'v_ApplyLipstick_g15_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 143]}},
#   'v_ApplyLipstick_g16_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 130]}},
#   'v_ApplyLipstick_g16_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 167]}},
#   'v_ApplyLipstick_g16_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 147]}},
#   'v_ApplyLipstick_g16_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 175]}},
#   'v_ApplyLipstick_g16_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 158]}},
#   'v_ApplyLipstick_g17_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 163]}},
#   'v_ApplyLipstick_g17_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 153]}},
#   'v_ApplyLipstick_g17_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 144]}},
#   'v_ApplyLipstick_g17_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 127]}},
#   'v_ApplyLipstick_g17_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 143]}},
#   'v_ApplyLipstick_g18_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 105]}},
#   'v_ApplyLipstick_g18_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 141]}},
#   'v_ApplyLipstick_g18_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 142]}},
#   'v_ApplyLipstick_g18_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 121]}},
#   'v_ApplyLipstick_g19_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 177]}},
#   'v_ApplyLipstick_g19_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 113]}},
#   'v_ApplyLipstick_g19_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 156]}},
#   'v_ApplyLipstick_g19_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 157]}},
#   'v_ApplyLipstick_g20_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 98]}},
#   'v_ApplyLipstick_g20_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 109]}},
#   'v_ApplyLipstick_g20_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 195]}},
#   'v_ApplyLipstick_g20_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 141]}},
#   'v_ApplyLipstick_g20_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 91]}},
#   'v_ApplyLipstick_g21_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 86]}},
#   'v_ApplyLipstick_g21_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 158]}},
#   'v_ApplyLipstick_g21_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 144]}},
#   'v_ApplyLipstick_g21_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 194]}},
#   'v_ApplyLipstick_g21_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 133]}},
#   'v_ApplyLipstick_g22_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 179]}},
#   'v_ApplyLipstick_g22_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 177]}},
#   'v_ApplyLipstick_g22_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 170]}},
#   'v_ApplyLipstick_g22_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 178]}},
#   'v_ApplyLipstick_g22_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 264]}},
#   'v_ApplyLipstick_g22_c06': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 173]}},
#   'v_ApplyLipstick_g22_c07': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 90]}},
#   'v_ApplyLipstick_g23_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 213]}},
#   'v_ApplyLipstick_g23_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 153]}},
#   'v_ApplyLipstick_g23_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 136]}},
#   'v_ApplyLipstick_g23_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 219]}},
#   'v_ApplyLipstick_g24_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 115]}},
#   'v_ApplyLipstick_g24_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 220]}},
#   'v_ApplyLipstick_g24_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 118]}},
#   'v_ApplyLipstick_g24_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 118]}},
#   'v_ApplyLipstick_g24_c05': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 289]}},
#   'v_ApplyLipstick_g25_c01': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 162]}},
#   'v_ApplyLipstick_g25_c02': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 152]}},
#   'v_ApplyLipstick_g25_c03': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 187]}},
#   'v_ApplyLipstick_g25_c04': {'subset': 'training',
#    'annotations': {'label': 'ApplyLipstick', 'segment': [1, 202]}},
#   'v_Archery_g08_c01': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 364]}},
#   'v_Archery_g08_c02': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 117]}},
#   'v_Archery_g08_c03': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 327]}},
#   'v_Archery_g08_c04': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 344]}},
#   'v_Archery_g08_c05': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 368]}},
#   'v_Archery_g10_c01': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 112]}},
#   'v_Archery_g10_c02': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 141]}},
#   'v_Archery_g10_c03': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 204]}},
#   'v_Archery_g10_c04': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 209]}},
#   'v_Archery_g10_c05': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 189]}},
#   'v_Archery_g10_c06': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 177]}},
#   'v_Archery_g10_c07': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 127]}},
#   'v_Archery_g11_c01': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 195]}},
#   'v_Archery_g11_c02': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 304]}},
#   'v_Archery_g11_c03': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 297]}},
#   'v_Archery_g11_c04': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 260]}},
#   'v_Archery_g11_c05': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 212]}},
#   'v_Archery_g11_c06': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 245]}},
#   'v_Archery_g11_c07': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 266]}},
#   'v_Archery_g12_c01': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 356]}},
#   'v_Archery_g12_c02': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 399]}},
#   'v_Archery_g12_c03': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 437]}},
#   'v_Archery_g12_c04': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 196]}},
#   'v_Archery_g13_c01': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 151]}},
#   'v_Archery_g13_c02': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 149]}},
#   'v_Archery_g13_c03': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 162]}},
#   'v_Archery_g13_c04': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 168]}},
#   'v_Archery_g13_c05': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 187]}},
#   'v_Archery_g13_c06': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 166]}},
#   'v_Archery_g13_c07': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 192]}},
#   'v_Archery_g14_c02': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 222]}},
#   'v_Archery_g14_c03': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 171]}},
#   'v_Archery_g14_c04': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 246]}},
#   'v_Archery_g15_c01': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 112]}},
#   'v_Archery_g15_c02': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 186]}},
#   'v_Archery_g15_c03': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 187]}},
#   'v_Archery_g15_c04': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 205]}},
#   'v_Archery_g15_c05': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 177]}},
#   'v_Archery_g15_c06': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 176]}},
#   'v_Archery_g15_c07': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 177]}},
#   'v_Archery_g16_c01': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 153]}},
#   'v_Archery_g16_c02': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 227]}},
#   'v_Archery_g16_c03': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 208]}},
#   'v_Archery_g16_c04': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 120]}},
#   'v_Archery_g16_c05': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 264]}},
#   'v_Archery_g17_c01': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 148]}},
#   'v_Archery_g17_c02': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 96]}},
#   'v_Archery_g17_c03': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 98]}},
#   'v_Archery_g17_c04': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 68]}},
#   'v_Archery_g18_c01': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 169]}},
#   'v_Archery_g18_c02': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 293]}},
#   'v_Archery_g18_c03': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 201]}},
#   'v_Archery_g18_c04': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 170]}},
#   'v_Archery_g18_c05': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 154]}},
#   'v_Archery_g18_c06': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 162]}},
#   'v_Archery_g18_c07': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 142]}},
#   'v_Archery_g19_c01': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 132]}},
#   'v_Archery_g19_c02': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 92]}},
#   'v_Archery_g19_c03': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 161]}},
#   'v_Archery_g19_c04': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 94]}},
#   'v_Archery_g20_c02': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 87]}},
#   'v_Archery_g20_c05': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 122]}},
#   'v_Archery_g21_c01': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 103]}},
#   'v_Archery_g21_c02': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 177]}},
#   'v_Archery_g21_c03': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 220]}},
#   'v_Archery_g21_c04': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 207]}},
#   'v_Archery_g22_c01': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 67]}},
#   'v_Archery_g22_c02': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 72]}},
#   'v_Archery_g22_c03': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 93]}},
#   'v_Archery_g22_c04': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 75]}},
#   'v_Archery_g22_c05': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 70]}},
#   'v_Archery_g24_c01': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 93]}},
#   'v_Archery_g24_c02': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 243]}},
#   'v_Archery_g24_c03': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 112]}},
#   'v_Archery_g24_c04': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 123]}},
#   'v_Archery_g24_c05': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 129]}},
#   'v_Archery_g24_c06': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 124]}},
#   'v_Archery_g25_c01': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 210]}},
#   'v_Archery_g25_c02': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 191]}},
#   'v_Archery_g25_c03': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 205]}},
#   'v_Archery_g25_c04': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 261]}},
#   'v_Archery_g25_c05': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 206]}},
#   'v_Archery_g25_c06': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 237]}},
#   'v_Archery_g25_c07': {'subset': 'training',
#    'annotations': {'label': 'Archery', 'segment': [1, 135]}},
#   'v_BabyCrawling_g08_c01': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 207]}},
#   'v_BabyCrawling_g08_c02': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 113]}},
#   'v_BabyCrawling_g09_c04': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 208]}},
#   'v_BabyCrawling_g09_c05': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 106]}},
#   'v_BabyCrawling_g09_c06': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 121]}},
#   'v_BabyCrawling_g10_c03': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 102]}},
#   'v_BabyCrawling_g10_c04': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 186]}},
#   'v_BabyCrawling_g10_c05': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 122]}},
#   'v_BabyCrawling_g11_c01': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 108]}},
#   'v_BabyCrawling_g11_c02': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 105]}},
#   'v_BabyCrawling_g11_c04': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 111]}},
#   'v_BabyCrawling_g12_c01': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 105]}},
#   'v_BabyCrawling_g12_c05': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 187]}},
#   'v_BabyCrawling_g13_c01': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 143]}},
#   'v_BabyCrawling_g13_c02': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 128]}},
#   'v_BabyCrawling_g13_c03': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 112]}},
#   'v_BabyCrawling_g13_c04': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 150]}},
#   'v_BabyCrawling_g13_c06': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 169]}},
#   'v_BabyCrawling_g15_c02': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 223]}},
#   'v_BabyCrawling_g15_c06': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 166]}},
#   'v_BabyCrawling_g16_c03': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 173]}},
#   'v_BabyCrawling_g16_c04': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 209]}},
#   'v_BabyCrawling_g16_c05': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 225]}},
#   'v_BabyCrawling_g16_c06': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 193]}},
#   'v_BabyCrawling_g17_c04': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 176]}},
#   'v_BabyCrawling_g18_c01': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 200]}},
#   'v_BabyCrawling_g18_c02': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 229]}},
#   'v_BabyCrawling_g18_c03': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 166]}},
#   'v_BabyCrawling_g18_c04': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 206]}},
#   'v_BabyCrawling_g18_c05': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 174]}},
#   'v_BabyCrawling_g18_c06': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 182]}},
#   'v_BabyCrawling_g19_c02': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 172]}},
#   'v_BabyCrawling_g20_c01': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 263]}},
#   'v_BabyCrawling_g21_c01': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 153]}},
#   'v_BabyCrawling_g21_c02': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 120]}},
#   'v_BabyCrawling_g21_c03': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 147]}},
#   'v_BabyCrawling_g21_c04': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 191]}},
#   'v_BabyCrawling_g23_c01': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 118]}},
#   'v_BabyCrawling_g24_c02': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 181]}},
#   'v_BabyCrawling_g24_c03': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 126]}},
#   'v_BabyCrawling_g24_c04': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 119]}},
#   'v_BabyCrawling_g24_c05': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 114]}},
#   'v_BabyCrawling_g24_c06': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 182]}},
#   'v_BabyCrawling_g25_c04': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 160]}},
#   'v_BabyCrawling_g25_c06': {'subset': 'training',
#    'annotations': {'label': 'BabyCrawling', 'segment': [1, 250]}},
#   'v_BalanceBeam_g08_c01': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 142]}},
#   'v_BalanceBeam_g08_c03': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 127]}},
#   'v_BalanceBeam_g08_c04': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 118]}},
#   'v_BalanceBeam_g09_c01': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 102]}},
#   'v_BalanceBeam_g09_c03': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 176]}},
#   'v_BalanceBeam_g09_c04': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 208]}},
#   'v_BalanceBeam_g10_c01': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 81]}},
#   'v_BalanceBeam_g10_c02': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 71]}},
#   'v_BalanceBeam_g10_c03': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 107]}},
#   'v_BalanceBeam_g11_c01': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 112]}},
#   'v_BalanceBeam_g11_c02': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 70]}},
#   'v_BalanceBeam_g11_c04': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 118]}},
#   'v_BalanceBeam_g12_c03': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 172]}},
#   'v_BalanceBeam_g13_c01': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 138]}},
#   'v_BalanceBeam_g13_c03': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 139]}},
#   'v_BalanceBeam_g13_c05': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 111]}},
#   'v_BalanceBeam_g14_c02': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 97]}},
#   'v_BalanceBeam_g14_c04': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 155]}},
#   'v_BalanceBeam_g15_c02': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 77]}},
#   'v_BalanceBeam_g15_c03': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 127]}},
#   'v_BalanceBeam_g16_c01': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 126]}},
#   'v_BalanceBeam_g16_c02': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 112]}},
#   'v_BalanceBeam_g16_c03': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 114]}},
#   'v_BalanceBeam_g16_c04': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 102]}},
#   'v_BalanceBeam_g17_c01': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 193]}},
#   'v_BalanceBeam_g17_c02': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 112]}},
#   'v_BalanceBeam_g17_c03': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 323]}},
#   'v_BalanceBeam_g17_c04': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 232]}},
#   'v_BalanceBeam_g17_c06': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 112]}},
#   'v_BalanceBeam_g18_c01': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 127]}},
#   'v_BalanceBeam_g18_c02': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 147]}},
#   'v_BalanceBeam_g18_c03': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 183]}},
#   'v_BalanceBeam_g18_c04': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 113]}},
#   'v_BalanceBeam_g19_c01': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 155]}},
#   'v_BalanceBeam_g19_c02': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 93]}},
#   'v_BalanceBeam_g19_c03': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 120]}},
#   'v_BalanceBeam_g19_c04': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 127]}},
#   'v_BalanceBeam_g21_c01': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 134]}},
#   'v_BalanceBeam_g21_c05': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 117]}},
#   'v_BalanceBeam_g22_c01': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 97]}},
#   'v_BalanceBeam_g22_c02': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 98]}},
#   'v_BalanceBeam_g22_c04': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 117]}},
#   'v_BalanceBeam_g23_c02': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 91]}},
#   'v_BalanceBeam_g23_c03': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 59]}},
#   'v_BalanceBeam_g23_c04': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 109]}},
#   'v_BalanceBeam_g24_c01': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 88]}},
#   'v_BalanceBeam_g25_c03': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 94]}},
#   'v_BalanceBeam_g25_c04': {'subset': 'training',
#    'annotations': {'label': 'BalanceBeam', 'segment': [1, 104]}},
#   'v_BandMarching_g08_c01': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 120]}},
#   'v_BandMarching_g08_c02': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 146]}},
#   'v_BandMarching_g08_c03': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 96]}},
#   'v_BandMarching_g08_c04': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 103]}},
#   'v_BandMarching_g08_c05': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 206]}},
#   'v_BandMarching_g08_c06': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 220]}},
#   'v_BandMarching_g09_c06': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 119]}},
#   'v_BandMarching_g09_c07': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 133]}},
#   'v_BandMarching_g11_c01': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 297]}},
#   'v_BandMarching_g11_c02': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 302]}},
#   'v_BandMarching_g11_c03': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 390]}},
#   'v_BandMarching_g11_c04': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 272]}},
#   'v_BandMarching_g11_c05': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 433]}},
#   'v_BandMarching_g11_c06': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 393]}},
#   'v_BandMarching_g11_c07': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 248]}},
#   'v_BandMarching_g12_c01': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 490]}},
#   'v_BandMarching_g12_c02': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 431]}},
#   'v_BandMarching_g12_c03': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 262]}},
#   'v_BandMarching_g12_c05': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 297]}},
#   'v_BandMarching_g12_c06': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 271]}},
#   'v_BandMarching_g13_c01': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 413]}},
#   'v_BandMarching_g13_c02': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 245]}},
#   'v_BandMarching_g13_c05': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 180]}},
#   'v_BandMarching_g14_c01': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 146]}},
#   'v_BandMarching_g14_c02': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 233]}},
#   'v_BandMarching_g14_c03': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 222]}},
#   'v_BandMarching_g14_c04': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 213]}},
#   'v_BandMarching_g14_c05': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 218]}},
#   'v_BandMarching_g14_c06': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 209]}},
#   'v_BandMarching_g15_c01': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 312]}},
#   'v_BandMarching_g15_c02': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 241]}},
#   'v_BandMarching_g15_c03': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 355]}},
#   'v_BandMarching_g15_c04': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 259]}},
#   'v_BandMarching_g15_c05': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 473]}},
#   'v_BandMarching_g15_c06': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 187]}},
#   'v_BandMarching_g15_c07': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 169]}},
#   'v_BandMarching_g16_c01': {'subset': 'training',
#    'annotations': {'label': 'BandMarching', 'segment': [1, 243]}},
#   'v_BandMarching_g16_c02': {'subset': 'training',
# ...
#   'v_Billiards_g14_c04': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 235]}},
#   'v_Billiards_g15_c01': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 331]}},
#   'v_Billiards_g15_c02': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 272]}},
#   'v_Billiards_g15_c03': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 237]}},
#   'v_Billiards_g15_c04': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 271]}},
#   'v_Billiards_g15_c05': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 247]}},
#   'v_Billiards_g15_c06': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 299]}},
#   'v_Billiards_g15_c07': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 335]}},
#   'v_Billiards_g16_c03': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 259]}},
#   'v_Billiards_g16_c04': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 295]}},
#   'v_Billiards_g16_c05': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 406]}},
#   'v_Billiards_g17_c03': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 403]}},
#   'v_Billiards_g18_c01': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 147]}},
#   'v_Billiards_g19_c01': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 289]}},
#   'v_Billiards_g19_c02': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 313]}},
#   'v_Billiards_g19_c03': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 213]}},
#   'v_Billiards_g19_c04': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 93]}},
#   'v_Billiards_g20_c01': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 294]}},
#   'v_Billiards_g20_c02': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 291]}},
#   'v_Billiards_g20_c03': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 230]}},
#   'v_Billiards_g20_c04': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 218]}},
#   'v_Billiards_g21_c05': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 363]}},
#   'v_Billiards_g22_c01': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 188]}},
#   'v_Billiards_g22_c02': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 167]}},
#   'v_Billiards_g24_c02': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 257]}},
#   'v_Billiards_g24_c03': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 304]}},
#   'v_Billiards_g24_c05': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 236]}},
#   'v_Billiards_g24_c06': {'subset': 'training',
#    'annotations': {'label': 'Billiards', 'segment': [1, 280]}},
#   'v_BlowDryHair_g08_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 369]}},
#   'v_BlowDryHair_g08_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 334]}},
#   'v_BlowDryHair_g08_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 492]}},
#   'v_BlowDryHair_g08_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 408]}},
#   'v_BlowDryHair_g08_c05': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 443]}},
#   'v_BlowDryHair_g08_c06': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 429]}},
#   'v_BlowDryHair_g08_c07': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 431]}},
#   'v_BlowDryHair_g09_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 625]}},
#   'v_BlowDryHair_g09_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 570]}},
#   'v_BlowDryHair_g10_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 211]}},
#   'v_BlowDryHair_g10_c06': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 178]}},
#   'v_BlowDryHair_g10_c07': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 178]}},
#   'v_BlowDryHair_g12_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 609]}},
#   'v_BlowDryHair_g12_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 585]}},
#   'v_BlowDryHair_g12_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 516]}},
#   'v_BlowDryHair_g12_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 632]}},
#   'v_BlowDryHair_g12_c05': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 323]}},
#   'v_BlowDryHair_g12_c06': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 271]}},
#   'v_BlowDryHair_g13_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 190]}},
#   'v_BlowDryHair_g13_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 171]}},
#   'v_BlowDryHair_g14_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 201]}},
#   'v_BlowDryHair_g14_c05': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 213]}},
#   'v_BlowDryHair_g15_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 98]}},
#   'v_BlowDryHair_g15_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 74]}},
#   'v_BlowDryHair_g15_c05': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 111]}},
#   'v_BlowDryHair_g16_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 120]}},
#   'v_BlowDryHair_g16_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 124]}},
#   'v_BlowDryHair_g16_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 122]}},
#   'v_BlowDryHair_g16_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 121]}},
#   'v_BlowDryHair_g17_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 259]}},
#   'v_BlowDryHair_g17_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 254]}},
#   'v_BlowDryHair_g17_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 352]}},
#   'v_BlowDryHair_g17_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 218]}},
#   'v_BlowDryHair_g17_c05': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 225]}},
#   'v_BlowDryHair_g18_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 292]}},
#   'v_BlowDryHair_g18_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 231]}},
#   'v_BlowDryHair_g18_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 285]}},
#   'v_BlowDryHair_g18_c05': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 243]}},
#   'v_BlowDryHair_g19_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 207]}},
#   'v_BlowDryHair_g19_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 210]}},
#   'v_BlowDryHair_g19_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 132]}},
#   'v_BlowDryHair_g19_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 89]}},
#   'v_BlowDryHair_g20_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 159]}},
#   'v_BlowDryHair_g20_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 226]}},
#   'v_BlowDryHair_g20_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 152]}},
#   'v_BlowDryHair_g20_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 105]}},
#   'v_BlowDryHair_g20_c05': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 194]}},
#   'v_BlowDryHair_g21_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 199]}},
#   'v_BlowDryHair_g21_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 111]}},
#   'v_BlowDryHair_g21_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 160]}},
#   'v_BlowDryHair_g21_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 132]}},
#   'v_BlowDryHair_g21_c05': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 148]}},
#   'v_BlowDryHair_g21_c06': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 146]}},
#   'v_BlowDryHair_g22_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 125]}},
#   'v_BlowDryHair_g22_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 166]}},
#   'v_BlowDryHair_g22_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 181]}},
#   'v_BlowDryHair_g23_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 393]}},
#   'v_BlowDryHair_g23_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 157]}},
#   'v_BlowDryHair_g23_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 187]}},
#   'v_BlowDryHair_g23_c05': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 381]}},
#   'v_BlowDryHair_g23_c06': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 284]}},
#   'v_BlowDryHair_g23_c07': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 459]}},
#   'v_BlowDryHair_g24_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 103]}},
#   'v_BlowDryHair_g24_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 85]}},
#   'v_BlowDryHair_g24_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 102]}},
#   'v_BlowDryHair_g24_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 98]}},
#   'v_BlowDryHair_g25_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 71]}},
#   'v_BlowDryHair_g25_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 127]}},
#   'v_BlowDryHair_g25_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 119]}},
#   'v_BlowDryHair_g25_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowDryHair', 'segment': [1, 71]}},
#   'v_BlowingCandles_g08_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 77]}},
#   'v_BlowingCandles_g08_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 86]}},
#   'v_BlowingCandles_g09_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 88]}},
#   'v_BlowingCandles_g09_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 94]}},
#   'v_BlowingCandles_g09_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 178]}},
#   'v_BlowingCandles_g10_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 83]}},
#   'v_BlowingCandles_g10_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 85]}},
#   'v_BlowingCandles_g11_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 72]}},
#   'v_BlowingCandles_g11_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 52]}},
#   'v_BlowingCandles_g11_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 137]}},
#   'v_BlowingCandles_g13_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 96]}},
#   'v_BlowingCandles_g14_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 233]}},
#   'v_BlowingCandles_g14_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 130]}},
#   'v_BlowingCandles_g14_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 152]}},
#   'v_BlowingCandles_g14_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 154]}},
#   'v_BlowingCandles_g15_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 139]}},
#   'v_BlowingCandles_g15_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 58]}},
#   'v_BlowingCandles_g15_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 67]}},
#   'v_BlowingCandles_g15_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 77]}},
#   'v_BlowingCandles_g16_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 236]}},
#   'v_BlowingCandles_g16_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 71]}},
#   'v_BlowingCandles_g16_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 53]}},
#   'v_BlowingCandles_g16_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 162]}},
#   'v_BlowingCandles_g17_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 69]}},
#   'v_BlowingCandles_g17_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 168]}},
#   'v_BlowingCandles_g17_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 168]}},
#   'v_BlowingCandles_g17_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 280]}},
#   'v_BlowingCandles_g18_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 92]}},
#   'v_BlowingCandles_g18_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 127]}},
#   'v_BlowingCandles_g19_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 54]}},
#   'v_BlowingCandles_g19_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 52]}},
#   'v_BlowingCandles_g20_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 232]}},
#   'v_BlowingCandles_g20_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 62]}},
#   'v_BlowingCandles_g20_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 115]}},
#   'v_BlowingCandles_g20_c04': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 127]}},
#   'v_BlowingCandles_g21_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 96]}},
#   'v_BlowingCandles_g22_c01': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 137]}},
#   'v_BlowingCandles_g22_c02': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 67]}},
#   'v_BlowingCandles_g22_c03': {'subset': 'training',
#    'annotations': {'label': 'BlowingCandles', 'segment': [1, 52]}},
#   ...}}
